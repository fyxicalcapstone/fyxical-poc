# %%
print("All tables in fyxical_poc:")
for table in client.list_tables("fyxical_poc"):
    print(f"  📋 {table.table_id}")
# Out:
# All tables in fyxical_poc:
#   📋 ml_predictions
#   📋 patient_intake
#   📋 patient_pathways
